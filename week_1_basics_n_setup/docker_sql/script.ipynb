# %%
import pandas as pd
from sqlalchemy import create_engine
from time import time

# %%
df_p = pd.read_parquet('yellow_tripdata_2024-04.parquet')

# %%
df_p.shape
# Out:
# (3514289, 19)

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
print(pd.io.sql.get_schema(df_p, name='yellow_taxi_data', con=engine))
# Out:
# CREATE TABLE yellow_taxi_data (
# 	"VendorID" INTEGER,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count FLOAT(53),
# 	trip_distance FLOAT(53),
# 	"RatecodeID" FLOAT(53),
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" INTEGER,
# 	"DOLocationID" INTEGER,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53),
# 	"Airport_fee" FLOAT(53)
# )

# %%
# df_iter = pd.read_csv('yellow_tripdata_2024-04.csv', iterator= True, chunksize=100000, low_memory=False)

# %%
while True:
    try:
        t_start = time()

#         df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
#         df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)

        df_p.to_sql(name='yellow_taxi_data', con=engine, if_exists='replace', chunksize=100000)

        t_end = time()

        print('Inserted another chunk, took %.3f second' % (t_end - t_start))
    except StopIteration:
        # StopIteration is raised when the iterator is exhausted
        print('All data processed.')
        break
    except Exception as e:
        # Handle other exceptions
        print(f'An error occurred: {e}')
        # Optionally, you can log the error or take other actions
# Out:
# Inserted another chunk, took 415.760 second
# Inserted another chunk, took 402.398 second
# Inserted another chunk, took 413.761 second
# Inserted another chunk, took 538.856 second
# Inserted another chunk, took 589.256 second
# Inserted another chunk, took 576.391 second
# Inserted another chunk, took 566.092 second
# Inserted another chunk, took 565.661 second
# Inserted another chunk, took 546.184 second
# Inserted another chunk, took 469.350 second
# Inserted another chunk, took 755.221 second
# Inserted another chunk, took 820.563 second
# Inserted another chunk, took 916.305 second
# Inserted another chunk, took 917.081 second
# Inserted another chunk, took 658.944 second
# Inserted another chunk, took 634.870 second
# Inserted another chunk, took 668.378 second
# Inserted another chunk, took 571.044 second
# Inserted another chunk, took 509.269 second
# Inserted another chunk, took 488.406 second
# Inserted another chunk, took 530.243 second
# Inserted another chunk, took 543.027 second
# Inserted another chunk, took 519.098 second
# Inserted another chunk, took 426.696 second
# Inserted another chunk, took 397.827 second
# Inserted another chunk, took 389.581 second
# Inserted another chunk, took 388.364 second
# Inserted another chunk, took 2557.153 second
# Inserted another chunk, took 423.930 second
# Inserted another chunk, took 435.759 second
# Inserted another chunk, took 437.804 second
# Inserted another chunk, took 448.297 second
# Inserted another chunk, took 407.433 second
# Inserted another chunk, took 424.612 second
# Inserted another chunk, took 422.939 second
# Inserted another chunk, took 392.946 second
# Inserted another chunk, took 1831.448 second
# Inserted another chunk, took 700.527 second
# Inserted another chunk, took 704.507 second
# Inserted another chunk, took 710.773 second
# Inserted another chunk, took 467.698 second
# Inserted another chunk, took 449.522 second
# Inserted another chunk, took 453.367 second
# Inserted another chunk, took 408.382 second
# Inserted another chunk, took 1187.855 second
# Inserted another chunk, took 376.379 second
# Inserted another chunk, took 378.191 second
# Inserted another chunk, took 390.955 second
# Inserted another chunk, took 390.510 second
# Inserted another chunk, took 2172.002 second
# Inserted another chunk, took 391.131 second
# Inserted another chunk, took 389.907 second
# Inserted another chunk, took 392.115 second
# Inserted another chunk, took 436.584 second
# Inserted another chunk, took 503.549 second
# Inserted another chunk, took 470.750 second
# Inserted another chunk, took 447.168 second
# Inserted another chunk, took 448.034 second
# Inserted another chunk, took 443.322 second
# Inserted another chunk, took 437.569 second
# Inserted another chunk, took 416.667 second
# Inserted another chunk, took 429.600 second
# Inserted another chunk, took 401.604 second
# Inserted another chunk, took 395.114 second
# Inserted another chunk, took 425.746 second
# Inserted another chunk, took 391.129 second
# Inserted another chunk, took 385.248 second
# Inserted another chunk, took 474.987 second
# Inserted another chunk, took 549.333 second
# Inserted another chunk, took 550.228 second
# Inserted another chunk, took 474.060 second
# Inserted another chunk, took 444.851 second
# Inserted another chunk, took 28349.014 second
# Inserted another chunk, took 651.746 second
# Inserted another chunk, took 646.070 second
# Inserted another chunk, took 599.874 second
# Inserted another chunk, took 1405.058 second
# Inserted another chunk, took 631.788 second
# Inserted another chunk, took 645.219 second
# Inserted another chunk, took 648.173 second
# Inserted another chunk, took 633.355 second
# Inserted another chunk, took 652.159 second
# Inserted another chunk, took 648.954 second
# Inserted another chunk, took 493.169 second
# Inserted another chunk, took 422.566 second
# Inserted another chunk, took 399.232 second
# Inserted another chunk, took 372.991 second
# Inserted another chunk, took 371.515 second
# Inserted another chunk, took 402.520 second
# Inserted another chunk, took 405.234 second
# Inserted another chunk, took 395.850 second
# Inserted another chunk, took 397.455 second
# Inserted another chunk, took 554.964 second
# Inserted another chunk, took 578.876 second
# Inserted another chunk, took 516.418 second
# Inserted another chunk, took 435.757 second
# Inserted another chunk, took 477.800 second
# Inserted another chunk, took 593.963 second
# Inserted another chunk, took 574.494 second
# Inserted another chunk, took 604.037 second
# Inserted another chunk, took 617.610 second
# Inserted another chunk, took 575.264 second
# Inserted another chunk, took 459.029 second
# Inserted another chunk, took 459.173 second
# Inserted another chunk, took 448.300 second
# Inserted another chunk, took 498.035 second
# Inserted another chunk, took 629.374 second
# Inserted another chunk, took 611.805 second
# Inserted another chunk, took 670.888 second
# Inserted another chunk, took 694.833 second
# Inserted another chunk, took 671.719 second
# Inserted another chunk, took 762.323 second
# Inserted another chunk, took 692.577 second
# Inserted another chunk, took 786.852 second
# Inserted another chunk, took 510.670 second
# Inserted another chunk, took 396.173 second
# Inserted another chunk, took 390.069 second
# Inserted another chunk, took 474.342 second
# Inserted another chunk, took 532.965 second
# Inserted another chunk, took 585.466 second
# Inserted another chunk, took 570.702 second
# Inserted another chunk, took 646.343 second
# Inserted another chunk, took 633.717 second
# Inserted another chunk, took 996.699 second
# Inserted another chunk, took 978.128 second
# Inserted another chunk, took 11854.878 second
# Inserted another chunk, took 398.846 second
# Inserted another chunk, took 389.773 second
# Inserted another chunk, took 372.135 second
# Inserted another chunk, took 370.544 second
# Inserted another chunk, took 370.403 second
# Inserted another chunk, took 4456.021 second
# Inserted another chunk, took 388.348 second
# Inserted another chunk, took 371.227 second
# Inserted another chunk, took 369.908 second
# Inserted another chunk, took 372.955 second
# Inserted another chunk, took 736.689 second
# Inserted another chunk, took 397.468 second
# Inserted another chunk, took 390.029 second
# Inserted another chunk, took 373.657 second
# Inserted another chunk, took 371.260 second
# Inserted another chunk, took 372.024 second
# Inserted another chunk, took 1197.281 second
# Inserted another chunk, took 396.342 second
# Inserted another chunk, took 396.610 second
# Inserted another chunk, took 395.857 second
# Inserted another chunk, took 398.375 second
# Inserted another chunk, took 630.176 second
# Inserted another chunk, took 599.978 second
# Inserted another chunk, took 582.171 second
# Inserted another chunk, took 587.477 second
# Inserted another chunk, took 589.242 second
# Inserted another chunk, took 599.976 second
# Inserted another chunk, took 9250.343 second
# Inserted another chunk, took 1555.807 second
# Inserted another chunk, took 1395.754 second
# Inserted another chunk, took 1384.628 second
# Inserted another chunk, took 1102.965 second
# Inserted another chunk, took 15987.011 second
# Inserted another chunk, took 424.175 second
# Inserted another chunk, took 414.016 second
# Inserted another chunk, took 371.001 second
# Inserted another chunk, took 369.674 second
# Inserted another chunk, took 370.661 second
# Inserted another chunk, took 481.642 second
# Inserted another chunk, took 705.940 second
# Inserted another chunk, took 1028.842 second
# Inserted another chunk, took 953.743 second
# Inserted another chunk, took 709.831 second
# Inserted another chunk, took 505.754 second
# Inserted another chunk, took 491.941 second
# Inserted another chunk, took 488.121 second
# Inserted another chunk, took 486.458 second
# Inserted another chunk, took 508.697 second
# Inserted another chunk, took 515.337 second
# Inserted another chunk, took 490.625 second
# Inserted another chunk, took 522.566 second
# Inserted another chunk, took 551.785 second
# Inserted another chunk, took 589.040 second
# Inserted another chunk, took 441.857 second
# Inserted another chunk, took 442.156 second
# Inserted another chunk, took 398.196 second
# Inserted another chunk, took 410.466 second
# Inserted another chunk, took 406.210 second
# Inserted another chunk, took 386.335 second
# Inserted another chunk, took 41755.652 second
# Inserted another chunk, took 458.554 second
# Inserted another chunk, took 1503.304 second
# Inserted another chunk, took 439.345 second
# Inserted another chunk, took 382.348 second
# Inserted another chunk, took 21884.312 second
# Inserted another chunk, took 461.123 second
# Inserted another chunk, took 17975.745 second
# Inserted another chunk, took 450.061 second
# Inserted another chunk, took 660.305 second
# Inserted another chunk, took 616.790 second
# Inserted another chunk, took 572.476 second
# Inserted another chunk, took 700.928 second
# Inserted another chunk, took 514.815 second
# Inserted another chunk, took 416.433 second
# Inserted another chunk, took 400.845 second
# Inserted another chunk, took 524.093 second
# Inserted another chunk, took 638.412 second
# Inserted another chunk, took 594.992 second
# Inserted another chunk, took 592.100 second
# Inserted another chunk, took 550.713 second
# Inserted another chunk, took 515.838 second
# Inserted another chunk, took 458.330 second
# Inserted another chunk, took 466.808 second
# Inserted another chunk, took 391.649 second
# Inserted another chunk, took 398.933 second
# Inserted another chunk, took 426.492 second
# Inserted another chunk, took 523.864 second
# Inserted another chunk, took 498.820 second
# Inserted another chunk, took 529.829 second
# Inserted another chunk, took 521.580 second
# Inserted another chunk, took 545.590 second
# Inserted another chunk, took 557.317 second
# Inserted another chunk, took 13270.608 second
# Inserted another chunk, took 398.307 second
# Inserted another chunk, took 471.672 second
# Inserted another chunk, took 482.208 second
# Inserted another chunk, took 427.468 second
# Inserted another chunk, took 390.819 second
# Inserted another chunk, took 382.551 second
# Inserted another chunk, took 371.924 second
# Inserted another chunk, took 370.843 second
